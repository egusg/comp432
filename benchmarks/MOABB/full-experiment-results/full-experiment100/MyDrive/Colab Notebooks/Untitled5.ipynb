# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Set the working directory (change 'my_benchmarks' to your preferred subdirectory within your Drive)
working_directory = '/content/drive/My Drive/project432'

# Create the working directory if it doesn't exist
if not os.path.exists(working_directory):
    os.makedirs(working_directory)

# Change to the working directory
os.chdir(working_directory)

# Check if the 'benchmarks' repo is already cloned
if not os.path.exists('benchmarks'):
    # !git clone https://github.com/speechbrain/benchmarks.git
else:
    print('Benchmarks repository already exists.')

# Change to the benchmarks directory
os.chdir('benchmarks')

# Initialize and update submodules if they haven't been already
if not os.path.exists('speechbrain'):
    # !git submodule update --init --recursive

# Change to the speechbrain directory
os.chdir('speechbrain')

# Install Python requirements if not already installed
requirements_path = 'requirements.txt'
if not os.path.isfile(requirements_path):
    # !pip install -r requirements.txt
else:
    print('Requirements already satisfied.')

# Install the package in editable mode if not already installed
# (This will not be persistent across sessions, so it will run every time)
# !pip install -e .

# Change to the MOABB benchmarks directory
moabb_dir = '/content/drive/My Drive/project432/benchmarks/benchmarks/MOABB'
os.chdir(moabb_dir)

# Install base dependencies if not already installed
base_requirements_path = '../../requirements.txt'
if not os.path.isfile(base_requirements_path):
    # !pip install -r ../../requirements.txt
else:
    print('Base dependencies already satisfied.')

# Install additional dependencies if not already installed
extra_requirements_path = 'extra-requirements.txt'
if not os.path.isfile(extra_requirements_path):
    # !pip install -r extra-requirements.txt
else:
    print('Extra requirements already satisfied.')

# Set the PYTHONPATH environment variable
# %env PYTHON_PATH=$moabb_dir
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'benchmarks'...
# remote: Enumerating objects: 1402, done.
# remote: Counting objects: 100% (1344/1344), done.
# remote: Compressing objects: 100% (593/593), done.
# remote: Total 1402 (delta 772), reused 1161 (delta 680), pack-reused 58
# Receiving objects: 100% (1402/1402), 1.15 MiB | 7.21 MiB/s, done.
# Resolving deltas: 100% (778/778), done.
# Updating files: 100% (182/182), done.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Obtaining file:///content/drive/My%20Drive/project432/benchmarks/speechbrain
# ERROR: file:///content/drive/My%20Drive/project432/benchmarks/speechbrain does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Base dependencies already satisfied.
# Extra requirements already satisfied.
# ...

# %%
import os

# Use the correct path to the directory where 'train.py' is located
# Note the removal of the space in 'MyDrive' which is a common mistake when referencing the mounted drive path.
working_directory = '/content/drive/MyDrive/project432/benchmarks/MOABB'

# Change to the working directory
os.chdir(working_directory)

# Verify the current working directory and list the files to ensure 'train.py' is there
print("Current Working Directory:", os.getcwd())
print("Directory Contents:", os.listdir())

# Now run the train.py script with the provided hyperparameters and arguments
# Assuming 'train.py' is in the current directory
# !python train.py hparams/MotorImagery/BNCI2014001/EEGNet.yaml --data_folder=eeg_data --cached_data_folder=eeg_pickled_data --output_folder=results/MotorImagery/BNCI2014001/ --target_subject_idx=0 --target_session_idx=1 --data_iterator_name=leave-one-session-out
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-b29cbcd17fdc> in <cell line: 8>()
#       6
#       7 # Change to the working directory
# ----> 8 os.chdir(working_directory)
#       9
#      10 # Verify the current working directory and list the files to ensure 'train.py' is there
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/project432/benchmarks/MOABB'
