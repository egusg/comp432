# %%
new_index = 1  # Index to track the position to insert unique elements
nums = [0,0,1,1,1,2,2,3,3,4]
new_index = 1
for i in range(1, len(nums)):
        if nums[i] != nums[i - 1]:
            nums[new_index] = nums[i]
            new_index += 1

nums = nums[:new_index]
print(nums)
# Out:
# [0, 1, 2, 3, 4]
