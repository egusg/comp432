# %% [markdown]
# # **Hyperparameter Tuning**
#
# When using a machine learning model there are often set of hyperparamers to set carefully. In this tutorial, we will show how you can do hyperparameter tuning with [Orion](https://orion.readthedocs.io/en/stable/).
#
# ## *What is an hyperparameter?*
# **Hyperparameters** are variables that need to be set before training a machine learning model. These parameters are responsible for governing the architecture of the model (architecture hyperparameters) or how the model is trained (optimization hyperparameters). For example, in a simple MLP, hyperparameters such as the learning rate, batch size, number of epochs, and number of neurons need to be set.
#
# However, the gradient for these variables **cannot be computed**, and thus, they have to be set manually by the users. Setting hyperparameters can be a challenging and time-consuming task, which may also require expertise in the specific problem at hand. If the task is computationally intensive and resources are limited, manual hyperparameter tuning is often necessary. This practice is commonly known as "*Graduate student descent*" because graduate students often manually adjust hyperparameters to optimize the model's performance. While this approach can be tedious, it is often effective in finding good hyperparameter values.
#
# If there are sufficient computational resources available, however, a more "scientific" approach can be taken by utilizing hyperparameter optimization techniques. There are many such techniques available in the literature, as this is an active area of research.
#
# ## Grid Search
# The simplest one is called **grid search**. Grid search simply creates a "grid" of all possible hyperparameter combinations.  For example, suppose we have a neural network model and we want to optimize the number of hidden layers and the learning rate. We might define a grid of possible values for these hyperparameters as follows:
#
# Number of hidden layers: [1, 2, 3, 4]
# Learning rate: [0.001, 0.01, 0.1, 1.0]
#
# This results in a grid of 16 possible combinations of hyperparameters (4 values for the number of hidden layers multiplied by 4 values for the learning rate). The grid search algorithm then trains the model using each of these hyperparameter combinations and selects the combination that gives the best performance on a validation set. Grid search is simple but computationally feasible for models with a small number of hyperparameters only (as the search space grows very fast when we have many hyperparameters)
#
# If we have more hyperparameters, other optimization techniques such as random search or Bayesian optimization may be more effective.
#
# ## Random Search
# **Random search simply** involves randomly sampling hyperparameters from a predefined range of possible values and selecting the best-performing combination of hyperparameters on the validation set.  This process is repeated a fixed number of times, or until a certain performance threshold is met. This solution can be more computationally efficient than grid search when the number of hyperparameters or the range of possible values is large.
#
# However, it may still require a large number of trials to find good hyperparameters, and more advanced optimization techniques such as Bayesian optimization may be more effective in some cases.
#
#
# ## Bayesian Optimization
# **Bayesian optimization** works by first defining a prior distribution over the hyperparameters, which captures our prior beliefs about them. The algorithm then uses the performance of the model on a validation set to update the prior distribution and construct a posterior distribution that reflects our updated beliefs about the hyperparameters.
#
# The algorithm then uses the posterior distribution to choose the next set of hyperparameters to evaluate, based on a trade-off between exploitation (choosing hyperparameters that are expected to perform well based on the current model) and exploration (choosing hyperparameters that may be less well-known but have a high potential for good performance).
#
# In this tutorial, we will use the Tree-structured Parzen Estimator (TPE). TPE is a variant of Bayesian optimization that aims to improve the efficiency of the optimization process by focusing on promising regions of the hyperparameter space.
#
# There are several toolkits for hyperparameter tuning available. In this tutorial, we will use [Orion](https://orion.readthedocs.io/en/stable/).

# %% [markdown]
# ## **Dataset**
#
# In this tutorial, we will do hyperparameter tuning on digit classification using the MNIST dataset.
#
#
# Let's first download the corpus:

# %%
# !wget -O mnist_train.npz "https://www.dropbox.com/scl/fi/001mmmnzmjrpckhie5obi/mnist_train.npz?rlkey=ylas84sw57rrh8u5s5qgozdhd&dl=0"
# !wget -O mnist_test.npz  "https://www.dropbox.com/scl/fi/u8nbdfx9v1w02j5k01f3f/mnist_test.npz?rlkey=5mjubm9xumzpisd0s4lrsfyqz&dl=0"
# Out:
# --2024-03-15 16:27:23--  https://www.dropbox.com/scl/fi/001mmmnzmjrpckhie5obi/mnist_train.npz?rlkey=ylas84sw57rrh8u5s5qgozdhd&dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com/cd/0/inline/CPIFgB3IyPLboT6ssfitMbnO_Ev6qGnKFArOEO6nf40DFmDolPKOj6Np2VjhOHfs42bHZBFcOcZpVsqFDtPma6izaLsiyoZ9tA68b-nM8CoA2N6SO1TMD_sGGFp86naPKNHr_vRxjtjKIa4gNi3wAn1U/file# [following]
# --2024-03-15 16:27:24--  https://uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com/cd/0/inline/CPIFgB3IyPLboT6ssfitMbnO_Ev6qGnKFArOEO6nf40DFmDolPKOj6Np2VjhOHfs42bHZBFcOcZpVsqFDtPma6izaLsiyoZ9tA68b-nM8CoA2N6SO1TMD_sGGFp86naPKNHr_vRxjtjKIa4gNi3wAn1U/file
# Resolving uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com (uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com)... 162.125.71.15, 2620:100:6022:15::a27d:420f
# Connecting to uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com (uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com)|162.125.71.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CPKLbV5pj5_kZ-jBYh1eKLMqoFy0nusFu7-nspsm7sBvwey4VthDzqDtBm7YMVcufQ071iN-PEFmioqEmVqNXTTqT45IvBT2prf8xqurTWtEsyzEQ2G5GSjXtTJeH1T9Ku3utf1CfVS4jX0j8KGyH8aYU9YTOejwNvZNDddB_OksTvk0YCB4W9yDpuJ-fSYVJFh_Up5zSGh7S2GZAHKkESNSzbPCJTbFP8JKG83glcrjBnxi5hR4NvCDrVQyeiGoRqlYk82_LLf39byLUJPDjxGalNND6MbJdFMeJsJHqQwLC2Q_pEx5gLGzJvZ0T26ELcSTlKnhMBc2XbQuXw1xpVOS7iSkkFdmMfqz-0iI2YMZ7n5esvICHp1Vuir3_iloBqA/file [following]
# --2024-03-15 16:27:25--  https://uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com/cd/0/inline2/CPKLbV5pj5_kZ-jBYh1eKLMqoFy0nusFu7-nspsm7sBvwey4VthDzqDtBm7YMVcufQ071iN-PEFmioqEmVqNXTTqT45IvBT2prf8xqurTWtEsyzEQ2G5GSjXtTJeH1T9Ku3utf1CfVS4jX0j8KGyH8aYU9YTOejwNvZNDddB_OksTvk0YCB4W9yDpuJ-fSYVJFh_Up5zSGh7S2GZAHKkESNSzbPCJTbFP8JKG83glcrjBnxi5hR4NvCDrVQyeiGoRqlYk82_LLf39byLUJPDjxGalNND6MbJdFMeJsJHqQwLC2Q_pEx5gLGzJvZ0T26ELcSTlKnhMBc2XbQuXw1xpVOS7iSkkFdmMfqz-0iI2YMZ7n5esvICHp1Vuir3_iloBqA/file
# Reusing existing connection to uc2aba123a6255e0829de46a24d6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 9861168 (9.4M) [application/octet-stream]
# Saving to: ‘mnist_train.npz’
#
# mnist_train.npz     100%[===================>]   9.40M  7.23MB/s    in 1.3s
#
# 2024-03-15 16:27:28 (7.23 MB/s) - ‘mnist_train.npz’ saved [9861168/9861168]
#
# --2024-03-15 16:27:28--  https://www.dropbox.com/scl/fi/u8nbdfx9v1w02j5k01f3f/mnist_test.npz?rlkey=5mjubm9xumzpisd0s4lrsfyqz&dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com/cd/0/inline/CPKtdJowbhmyUYz_kcyUJ5CORJuE6IJXdajeXwkGf6yBScRvWCyZTjlBUfOSjcvqUSe6N05gAcOJefnMXprvp-l7YFMWJMZqNlRCgkh2iPC8T8rpxqgeez8YNO1nYFgAX8FR-47SC2VYLwo0l0scipf4/file# [following]
# --2024-03-15 16:27:30--  https://uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com/cd/0/inline/CPKtdJowbhmyUYz_kcyUJ5CORJuE6IJXdajeXwkGf6yBScRvWCyZTjlBUfOSjcvqUSe6N05gAcOJefnMXprvp-l7YFMWJMZqNlRCgkh2iPC8T8rpxqgeez8YNO1nYFgAX8FR-47SC2VYLwo0l0scipf4/file
# Resolving uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com (uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com)... 162.125.70.15, 2620:100:6021:15::a27d:410f
# Connecting to uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com (uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com)|162.125.70.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CPJafWLf5dVUs1HE_CDyapyck8HPvBLWwmeFusPyFCDGvhFOdApS818BDOnO17tXWzLowc2Zmly7xzPvnRBaO7Wet9ghzqKV8dIVKDw5rr62IcL24cc-yEbqzsjYJIyCtBtLGpnJnt21Uj6wPDK_jVkedjKBYWp_AfHLFtv_pjTRHRFyq9ecuT1GTn3uq9OFLxomHyRsEmOg-IfHQ2nrHlDRV9lglhL2sMVny3T1xAWbSEJlMuqpzoQCfJnC2wx6PaPYbeNXOSxys6mz43uja-HGxhlDdjtXol5GznIYuDdbD419e8f3QnsxTe6Snh_iGpibVXWusbZNNl4ropjkz6HSsMDp2i1I1ktYFfHKvs0NKz_CeJPh9w_1A7URpJSqJhE/file [following]
# --2024-03-15 16:27:31--  https://uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com/cd/0/inline2/CPJafWLf5dVUs1HE_CDyapyck8HPvBLWwmeFusPyFCDGvhFOdApS818BDOnO17tXWzLowc2Zmly7xzPvnRBaO7Wet9ghzqKV8dIVKDw5rr62IcL24cc-yEbqzsjYJIyCtBtLGpnJnt21Uj6wPDK_jVkedjKBYWp_AfHLFtv_pjTRHRFyq9ecuT1GTn3uq9OFLxomHyRsEmOg-IfHQ2nrHlDRV9lglhL2sMVny3T1xAWbSEJlMuqpzoQCfJnC2wx6PaPYbeNXOSxys6mz43uja-HGxhlDdjtXol5GznIYuDdbD419e8f3QnsxTe6Snh_iGpibVXWusbZNNl4ropjkz6HSsMDp2i1I1ktYFfHKvs0NKz_CeJPh9w_1A7URpJSqJhE/file
# Reusing existing connection to uc0d66f42f9332eeb4dfcc35eab3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1640804 (1.6M) [application/octet-stream]
# Saving to: ‘mnist_test.npz’
#
# mnist_test.npz      100%[===================>]   1.56M  2.61MB/s    in 0.6s
#
# 2024-03-15 16:27:32 (2.61 MB/s) - ‘mnist_test.npz’ saved [1640804/1640804]

# %% [markdown]
# To make the hyperparameter optimization computationally feasible, we will only use a small fraction of the MNIST datasets. Specifically, we will use:
# - 1000 samples for training
# - 1000 samples for validation
#
# We can now install Orion:

# %%
# %%capture
# !pip install git+https://github.com/epistimio/orion.git@develop
# !pip install orion[profet]

# %% [markdown]
# # **Model**
#
# In this tutorial, we consider a simple MLP. We want to find proper values for the learning rate, batch size, number of epochs, and number of neurons.
# For the sake of compactness, we will implement a model with scikit-learn. Keep in mind, however, that Orion is a **black-box optimizer** that can be used with any toolkit, including *PyTorch*, *TensorFlow*, *Keras*, etc.
#
# Let's write a simple script for training the MLP with the MNIST data:

# %% [markdown]
# side note: black-box : you give an input and just get your output without knowing how it works

# %%
# %%file train.py

import argparse
import numpy as np
import sklearn
import sklearn.preprocessing
import sklearn.neural_network
from orion.client import report_objective # Orion

def train():
    parser = argparse.ArgumentParser(description='PyTorch MNIST Example')
    parser.add_argument('--batchsize', type=int, default=64,
                        help='input batch size for training (default: 64)')
    parser.add_argument('--epochs', type=int, default=10,
                        help='number of epochs to train (default: 14)')
    parser.add_argument('--lr', type=float, default=0.01,
                        help='learning rate (default: 1.0)')
    parser.add_argument('--neurons', type=int, default=100,
                        help='number of neurons (default: 100)')
    parser.add_argument('--eval', type=bool, default=False,
                        help='If True it prints the test error (default: False)')
    parser.add_argument("-f", required=False)
    args = parser.parse_args()

    with np.load("mnist_train.npz") as data:
        X_trn = data['X']
        y_trn = data['y']

    with np.load("mnist_test.npz") as data:
        X_tst = data['X']
        y_tst = data['y']

    # Select data
    X_valid = X_trn[1000:]
    y_valid = y_trn[1000:]

    X_trn = X_trn[0:1000]
    y_trn = y_trn[0:1000]

    # Data normalization
    scaler = sklearn.preprocessing.StandardScaler()
    scaler.fit(X_trn)
    X_trn = scaler.transform(X_trn)
    X_valid = scaler.transform(X_valid)


    # MLP classifier
    mlp = sklearn.neural_network.MLPClassifier(hidden_layer_sizes=(args.neurons),
                                              solver='sgd', batch_size=args.batchsize, max_iter=args.epochs,
                                              learning_rate_init=args.lr, momentum=0.9,
                                              verbose=False, random_state=0)
    # Training
    mlp.fit(X_trn, y_trn);

    valid_error = 100*(1 - mlp.score(X_valid, y_valid))
    print("Valid Error (\%): " + str(valid_error))

    report_objective(valid_error)

    if args.eval:
      test_error = 100*(1 - mlp.score(X_tst, y_tst))
      print("Test Error (\%): " + str(test_error))


if __name__ == '__main__':
    train()
# Out:
# Writing train.py

# %% [markdown]
# Let's see if the training script runs with a given set of hyperparameters:

# %%
# !python train.py --lr=0.1 --epochs=25 --batchsize=128 --neurons=20 --eval='True'
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.303389830508474
# [{'name': 'objective', 'type': 'objective', 'value': 15.303389830508474}]
# Test Error (\%): 36.33

# %% [markdown]
# The training script reports the validation and test errors. In this case, they are both pretty high because we are only using a small fraction of the MNIST corpus.

# %% [markdown]
# ##  **Random Search**
# Running a random search with Orion is very simple. You just need to specify the prior distribution of the targeted hyperparameters. See the [Orion documentation](https://orion.readthedocs.io/en/stable/user/searchspace.html#) for more information about the search space. As a first example, we are only optimizing the learning rate, keeping the other hyperparameters fixed:

# %%
# !orion hunt -n orion-tutorial1 --exp-max-trials=50 python train.py --lr~'loguniform(1e-4, 0.1)' --epochs=25 --batchsize=128 --neurons=20
# Out:
# 2024-03-10 18:17:10,037::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:17:10,235::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:17:16,618::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:17:17,204::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 77.72203389830509
# 2024-03-10 18:17:21,809::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.210169491525427
# 2024-03-10 18:17:27,214::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.46101694915254
# 2024-03-10 18:17:31,473::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.532203389830503
# 2024-03-10 18:17:36,526::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 18.569491525423732
# 2024-03-10 18:17:41,027::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 19.401694915254243
# 2024-03-10 18:17:45,340::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.188135593220341
# 2024-03-10 18:17:50,653::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 27.908474576271193
# 2024-03-10 18:17:54,928::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.301694915254238
# 2024-03-10 18:17:59,238::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 40.74067796610169
# 2024-03-10 18:18:04,429::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.91016949152542
# 2024-03-10 18:18:08,744::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.8728813559322
# 2024-03-10 18:18:13,040::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.003389830508475
# 2024-03-10 18:18:18,490::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.103389830508476
# 2024-03-10 18:18:22,764::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 23.2271186440678
# 2024-03-10 18:18:27,987::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 27.50847457627119
# 2024-03-10 18:18:32,905::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.471186440677965
# 2024-03-10 18:18:37,273::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 22.391525423728808
# 2024-03-10 18:18:42,848::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 28.423728813559322
# 2024-03-10 18:18:47,151::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 73.47457627118644
# 2024-03-10 18:18:51,638::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.11694915254237
# 2024-03-10 18:18:56,823::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 76.35084745762713
# 2024-03-10 18:19:01,182::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.874576271186438
# 2024-03-10 18:19:07,145::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.300000000000004
# 2024-03-10 18:19:11,524::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 41.8864406779661
# 2024-03-10 18:19:15,864::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 41.21694915254237
# 2024-03-10 18:19:21,272::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.708474576271183
# 2024-03-10 18:19:25,631::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 63.7
# 2024-03-10 18:19:30,218::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 51.98813559322034
# 2024-03-10 18:19:35,293::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 20.008474576271183
# 2024-03-10 18:19:39,771::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 73.26949152542372
# 2024-03-10 18:19:45,302::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.46610169491526
# 2024-03-10 18:19:49,690::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.422033898305088
# 2024-03-10 18:19:54,032::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 60.47118644067797
# 2024-03-10 18:19:59,456::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.532203389830512
# 2024-03-10 18:20:03,867::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.522033898305088
# 2024-03-10 18:20:08,383::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 42.20169491525424
# 2024-03-10 18:20:13,575::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 58.025423728813564
# 2024-03-10 18:20:18,013::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 18.07796610169492
# 2024-03-10 18:20:23,699::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.87796610169492
# 2024-03-10 18:20:28,079::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 19.08474576271186
# 2024-03-10 18:20:32,508::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 77.3135593220339
# 2024-03-10 18:20:37,950::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.547457627118643
# 2024-03-10 18:20:42,362::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 33.099999999999994
# 2024-03-10 18:20:47,036::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.25254237288135
# 2024-03-10 18:20:52,191::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 64.16271186440679
# 2024-03-10 18:20:56,609::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.635593220338983
# 2024-03-10 18:21:02,209::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 19.647457627118648
# 2024-03-10 18:21:06,616::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 46.16271186440678
# 2024-03-10 18:21:11,033::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.72542372881356
# Search finished successfully
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: 4d03b49ede70e47e7a3d8398d93ab045
#   evaluation: 15.188135593220341
#   params:
#     /lr: 0.08052
# start time: 2024-03-10 18:17:16.603332
# finish time: 2024-03-10 18:21:16.151727
# elapsed_time: 0:03:58.976015
#
#
# Hints
# =====
#
# Info
# ----
#
# To get more information on the experiment, run the command
#
# orion info --name orion-tutorial1 --version 1

# %% [markdown]
# We can run *orion-info** to check the best set of hyperparameters discovered:

# %%
# !orion info --name orion-tutorial1 --version 1
# Out:
# Identification
# ==============
# name: orion-tutorial1
# version: 1
# user: root
#
#
# Commandline
# ===========
# python train.py --lr~loguniform(1e-4, 0.1) --epochs=25 --batchsize=128 --neurons=20
#
#
# Config
# ======
# max trials: 50
# max broken: 3
# working dir:
#
#
# Algorithm
# =========
# random:
#     seed: None
#
#
# Space
# =====
# /lr: loguniform(0.0001, 0.1)
#
#
# Meta-data
# =========
# user: root
# datetime: 2024-03-10 18:17:16.603332
# orion version: 0.2.6.post343+g1b20511c
# VCS:
#
#
#
# Parent experiment
# =================
# root:
# parent:
# adapter:
#
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: 4d03b49ede70e47e7a3d8398d93ab045
#   evaluation: 15.188135593220341
#   params:
#     /lr: 0.08052
# start time: 2024-03-10 18:17:16.603332
# finish time: 2024-03-10 18:21:16.151727
# elapsed_time: 0:03:58.976015

# %% [markdown]
# Now, we can train the model with the best hyperparameters and check the performance on the test set.

# %%
# !python train.py --lr=0.08052 --epochs=25 --batchsize=128 --neurons=20 --eval='True'
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.188135593220341
# [{'name': 'objective', 'type': 'objective', 'value': 15.188135593220341}]
# Test Error (\%): 35.260000000000005

# %% [markdown]
# Normally, we run the hyperparameter tuning with more than one hyperparameters.Beyond the learning rate, we now consider the batch size, the number of epochs, and the number on neurons:

# %%
# !orion hunt -n orion-tutorial2 --exp-max-trials=50 python train.py  --lr~'loguniform(1e-4, 0.1)' --neurons~'uniform(10, 100, discrete=True)' --batchsize~'choices([32,64,128])' --epochs~'uniform(15, 50, discrete=True)'
# Out:
# 2024-03-10 18:22:58,381::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:22:58,518::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:23:02,250::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:23:03,030::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 38.657627118644065
# 2024-03-10 18:23:08,240::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (34) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.537288135593219
# 2024-03-10 18:23:15,379::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (38) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 28.89322033898305
# 2024-03-10 18:23:20,666::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (41) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.079661016949153
# 2024-03-10 18:23:25,953::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (19) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 40.7728813559322
# 2024-03-10 18:23:31,426::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (46) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.613559322033897
# 2024-03-10 18:23:36,259::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.559322033898303
# 2024-03-10 18:23:43,771::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (40) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.406779661016945
# 2024-03-10 18:23:49,303::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (29) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.450847457627123
# 2024-03-10 18:23:55,954::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (17) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.681355932203388
# 2024-03-10 18:24:00,421::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (33) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.71694915254237
# 2024-03-10 18:24:07,727::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (45) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.610169491525426
# 2024-03-10 18:24:14,409::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (27) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.603389830508476
# 2024-03-10 18:24:21,460::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.869491525423728
# 2024-03-10 18:24:26,500::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (41) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.494915254237283
# 2024-03-10 18:24:32,840::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (36) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.84406779661017
# 2024-03-10 18:24:38,217::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (47) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.881355932203387
# 2024-03-10 18:24:43,891::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 12.952542372881359
# 2024-03-10 18:24:50,448::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.910169491525426
# 2024-03-10 18:24:55,290::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (34) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 42.2677966101695
# 2024-03-10 18:25:01,177::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.493220338983049
# 2024-03-10 18:25:05,922::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (26) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 25.281355932203386
# 2024-03-10 18:25:11,271::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 14.328813559322029
# 2024-03-10 18:25:16,016::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (39) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 50.3457627118644
# 2024-03-10 18:25:21,106::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (27) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.962711864406785
# 2024-03-10 18:25:27,032::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 61.80847457627119
# 2024-03-10 18:25:31,917::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 28.5728813559322
# 2024-03-10 18:25:39,076::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (43) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.98474576271186
# 2024-03-10 18:25:44,053::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (15) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.99661016949153
# 2024-03-10 18:25:50,002::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (45) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 31.388135593220333
# 2024-03-10 18:25:55,075::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 17.015254237288136
# 2024-03-10 18:26:00,893::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (34) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.655932203389831
# 2024-03-10 18:26:06,958::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (39) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.65762711864407
# 2024-03-10 18:26:11,642::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (30) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.77796610169492
# 2024-03-10 18:26:17,673::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (21) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 17.515254237288136
# 2024-03-10 18:26:22,130::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 24.983050847457623
# 2024-03-10 18:26:28,690::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (46) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.689830508474577
# 2024-03-10 18:26:34,239::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (36) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.888135593220342
# 2024-03-10 18:26:39,531::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (35) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.979661016949152
# 2024-03-10 18:26:46,533::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (49) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.318644067796615
# 2024-03-10 18:26:58,666::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (43) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.072881355932198
# 2024-03-10 18:27:05,091::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (19) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.830508474576275
# 2024-03-10 18:27:11,594::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (17) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.991525423728813
# 2024-03-10 18:27:16,841::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (38) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.623728813559325
# 2024-03-10 18:27:24,071::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (40) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.683050847457622
# 2024-03-10 18:27:30,422::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (44) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.876271186440682
# 2024-03-10 18:27:38,929::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (43) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 16.69322033898305
# 2024-03-10 18:27:44,423::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (18) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 36.842372881355935
# 2024-03-10 18:27:50,739::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (24) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.18474576271187
# 2024-03-10 18:27:55,831::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (21) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.471186440677963
# Search finished successfully
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: e4752341fe119ceeec0e968e017d6f72
#   evaluation: 12.952542372881359
#   params:
#     /batchsize: 64
#     /epochs: 41
#     /lr: 0.03272
#     /neurons: 100
# start time: 2024-03-10 18:23:02.227110
# finish time: 2024-03-10 18:28:01.379445
# elapsed_time: 0:04:58.367799
#
#
# Hints
# =====
#
# Info
# ----
#
# To get more information on the experiment, run the command
#
# orion info --name orion-tutorial2 --version 1

# %%
# !orion info --name orion-tutorial2 --version 1
# Out:
# Identification
# ==============
# name: orion-tutorial2
# version: 1
# user: root
#
#
# Commandline
# ===========
# python train.py --lr~loguniform(1e-4, 0.1) --neurons~uniform(10, 100, discrete=True) --batchsize~choices([32,64,128]) --epochs~uniform(15, 50, discrete=True)
#
#
# Config
# ======
# max trials: 50
# max broken: 3
# working dir:
#
#
# Algorithm
# =========
# random:
#     seed: None
#
#
# Space
# =====
# /batchsize: choices([32, 64, 128])
# /epochs: uniform(15, 50, discrete=True)
# /lr: loguniform(0.0001, 0.1)
# /neurons: uniform(10, 100, discrete=True)
#
#
# Meta-data
# =========
# user: root
# datetime: 2024-03-10 18:23:02.227110
# orion version: 0.2.6.post343+g1b20511c
# VCS:
#
#
#
# Parent experiment
# =================
# root:
# parent:
# adapter:
#
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: e4752341fe119ceeec0e968e017d6f72
#   evaluation: 12.952542372881359
#   params:
#     /batchsize: 64
#     /epochs: 41
#     /lr: 0.03272
#     /neurons: 100
# start time: 2024-03-10 18:23:02.227110
# finish time: 2024-03-10 18:28:01.379445
# elapsed_time: 0:04:58.367799

# %%
# !python train.py --lr=0.03272 --epochs=41 --batchsize=64 --neurons=100 --eval='True'
# Out:
# Valid Error (\%): 12.952542372881359
# [{'name': 'objective', 'type': 'objective', 'value': 12.952542372881359}]
# Test Error (\%): 35.129999999999995

# %% [markdown]
# Often, you can try a good set of hyperparameters with a random search. However, when you increase the number of hyperparameters you need to increase the number of experiments as well. This makes it hard to use random search with a large number of hyperparameters to set.

# %% [markdown]
# # Tree-Structured Parzen Estimator (TPE)
#
# An alternative to random search is the TPE algorithm. If you want to use it, you need to create a config file with the hyperparameters that govern how TPE works.

# %%
# %%file tpe_config.cfg
# experiment:
#     algorithms:
#         tpe:
#             seed: null
#             n_initial_points: 10
#             n_ei_candidates: 10
#             gamma: 0.15
# Out:
# Writing tpe_config.cfg

# %% [markdown]
# n_ei_candidates and gamma manage the trade-off between exploration and exploitation.
#
# You can find more info on the role of each hyperparameter to set [here](https://orion.readthedocs.io/en/stable/user/algorithms.html#tpe).
#
# Let's run the hparam search with TPE:

# %%
# !orion hunt --config tpe_config.cfg -n orion-tutorial3 --exp-max-trials=50 python train.py --lr~'loguniform(1e-4, 0.1)' --neurons~'uniform(10, 100, discrete=True)' --batchsize~'choices([32,64,128])' --epochs~'uniform(15, 50, discrete=True)'
# Out:
# 2024-03-10 18:29:06,940::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:29:07,240::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:29:10,077::WARNING::orion.core.io.experiment_builder::algorithms is deprecated and will be removed in v0.4.0. Use algorithm instead.
# 2024-03-10 18:29:10,261::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# 2024-03-10 18:29:11,033::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 15.164406779661022
# 2024-03-10 18:29:18,214::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 23.296610169491526
# 2024-03-10 18:29:23,481::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (21) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 25.76440677966102
# 2024-03-10 18:29:28,888::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (46) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 18.369491525423733
# 2024-03-10 18:29:35,022::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.774576271186437
# 2024-03-10 18:29:41,731::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (44) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 23.37627118644068
# 2024-03-10 18:29:46,891::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (35) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.2406779661017
# 2024-03-10 18:29:51,877::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (28) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.457627118644067
# 2024-03-10 18:29:57,999::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (31) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 19.88305084745763
# 2024-03-10 18:30:03,080::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.372881355932197
# 2024-03-10 18:30:10,304::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (36) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.959322033898303
# 2024-03-10 18:30:15,650::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (36) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.822033898305087
# 2024-03-10 18:30:23,345::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (27) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.335593220338982
# 2024-03-10 18:30:28,956::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.711864406779661
# 2024-03-10 18:30:35,285::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (26) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 15.883050847457625
# 2024-03-10 18:30:39,872::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 15.064406779661022
# 2024-03-10 18:30:44,986::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.637288135593217
# 2024-03-10 18:30:50,191::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (27) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 18.13728813559322
# 2024-03-10 18:30:54,682::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.85254237288136
# 2024-03-10 18:31:01,031::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (27) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.720338983050851
# 2024-03-10 18:31:05,777::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (23) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.710169491525425
# 2024-03-10 18:31:11,280::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.550847457627114
# 2024-03-10 18:31:16,556::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.435593220338982
# 2024-03-10 18:31:21,402::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.903389830508473
# 2024-03-10 18:31:27,248::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (22) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.95254237288136
# 2024-03-10 18:31:32,088::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.459322033898303
# 2024-03-10 18:31:38,809::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 29.67457627118644
# 2024-03-10 18:31:43,466::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.389830508474576
# 2024-03-10 18:31:48,487::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (16) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.498305084745766
# 2024-03-10 18:31:54,045::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.38813559322034
# 2024-03-10 18:31:59,159::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (38) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.389830508474576
# 2024-03-10 18:32:06,412::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 12.89661016949153
# 2024-03-10 18:32:11,754::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 57.36101694915254
# 2024-03-10 18:32:18,072::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (33) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 35.28983050847457
# 2024-03-10 18:32:23,643::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.41186440677966
# 2024-03-10 18:32:31,901::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (38) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.838983050847453
# 2024-03-10 18:32:36,956::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.338983050847453
# 2024-03-10 18:32:43,373::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.489830508474576
# 2024-03-10 18:32:48,736::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# Valid Error (\%): 13.39661016949153
# 2024-03-10 18:32:55,428::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.101694915254235
# 2024-03-10 18:33:01,736::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (25) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.491525423728811
# 2024-03-10 18:33:07,736::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 14.094915254237284
# 2024-03-10 18:33:13,129::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.371186440677963
# 2024-03-10 18:33:18,407::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.525423728813557
# 2024-03-10 18:33:25,952::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.8
# 2024-03-10 18:33:31,325::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (37) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 24.33220338983051
# 2024-03-10 18:33:37,471::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (48) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.398305084745765
# 2024-03-10 18:33:43,161::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (47) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 35.77966101694915
# 2024-03-10 18:33:49,713::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (24) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.316949152542367
# 2024-03-10 18:33:55,321::WARNING::root::Script /content/train.py is not in a git repository. Code modification won't be detected.
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (24) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 13.589830508474577
# Search finished successfully
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: 340144905ba39d35b08a19d2d0798290
#   evaluation: 12.89661016949153
#   params:
#     /batchsize: 64
#     /epochs: 20
#     /lr: 0.03268
#     /neurons: 73
# start time: 2024-03-10 18:29:10.234556
# finish time: 2024-03-10 18:34:01.323960
# elapsed_time: 0:04:50.319816
#
#
# Hints
# =====
#
# Info
# ----
#
# To get more information on the experiment, run the command
#
# orion info --name orion-tutorial3 --version 1

# %%
# !orion info --name orion-tutorial3 --version 1
# Out:
# Identification
# ==============
# name: orion-tutorial3
# version: 1
# user: root
#
#
# Commandline
# ===========
# python train.py --lr~loguniform(1e-4, 0.1) --neurons~uniform(10, 100, discrete=True) --batchsize~choices([32,64,128]) --epochs~uniform(15, 50, discrete=True)
#
#
# Config
# ======
# max trials: 50
# max broken: 3
# working dir:
#
#
# Algorithm
# =========
# tpe:
#     equal_weight: False
#     full_weight_num: 25
#     gamma: 0.15
#     max_retry: 100
#     n_ei_candidates: 10
#     n_initial_points: 10
#     parallel_strategy:
#         of_type: StatusBasedParallelStrategy
#         strategy_configs:
#             broken:
#                 of_type: MaxParallelStrategy
#     prior_weight: 1.0
#     seed: None
#
#
# Space
# =====
# /batchsize: choices([32, 64, 128])
# /epochs: uniform(15, 50, discrete=True)
# /lr: loguniform(0.0001, 0.1)
# /neurons: uniform(10, 100, discrete=True)
#
#
# Meta-data
# =========
# user: root
# datetime: 2024-03-10 18:29:10.234556
# orion version: 0.2.6.post343+g1b20511c
# VCS:
#
#
#
# Parent experiment
# =================
# root:
# parent:
# adapter:
#
#
# Stats
# =====
# completed: True
# trials completed: 50
# best trial:
#   id: 340144905ba39d35b08a19d2d0798290
#   evaluation: 12.89661016949153
#   params:
#     /batchsize: 64
#     /epochs: 20
#     /lr: 0.03268
#     /neurons: 73
# start time: 2024-03-10 18:29:10.234556
# finish time: 2024-03-10 18:34:01.323960
# elapsed_time: 0:04:50.319816

# %%
# !python train.py --lr=0.03268 --epochs=20 --batchsize=64 --neurons=73 --eval='True'
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Valid Error (\%): 12.89661016949153
# [{'name': 'objective', 'type': 'objective', 'value': 12.89661016949153}]
# Test Error (\%): 29.330000000000002

# %% [markdown]
# Note that not always TPE produces results better than random optimization. In this specific task, due to the little data used for training and validation, there is a lot of "noise" in the model training and evaluation. In this scenario, TPE can perform worse  or better than random search based on the initialization seed.
